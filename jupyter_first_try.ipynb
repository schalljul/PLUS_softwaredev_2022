# %%
from matplotlib import pyplot as plt
import numpy as np
# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()
# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
# %run newfile.py
# Out:
# ['C:\\Users\\s1021929', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python37.zip', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3', '', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages', 'C:\\Program Files\\ArcGIS\\Pro\\bin', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\future-0.18.2-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pytz-2020.1-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32_ctypes-0.2.0-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32security', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\sympy-1.5.1-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\s1021929\\.ipython']
#
# Please wait a moment while I gather a list of all available modules...
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# AddGeometryAttributes _dummy_thread       flowdistance        ordlookup
# AddVehicleRoutingProblemBreaks _elementtree        fnmatch             os
# AddVehicleRoutingProblemRoutes _functools          formatter           osgeo
# AggregatePointsCore _hashlib            fractions           osgeo_utils
# BatchDefineSR       _heapq              ftplib              overlaylayers_sa
# BatchProject        _imp                functools           packaging
# BatchPyramids       _io                 future              pandas
# BatchStats          _json               ga_desktop_aggregatepoints pandocfilters
# BivariateDependence _locale             ga_desktop_appenddata parser
# CalculateAreas      _lsprof             ga_desktop_calculatedensity parso
# CalculateDensity_standard _lzma               ga_desktop_calculatefield past
# CalculateDistanceBand _markupbase         ga_desktop_calculatemotionstatistics pathlib
# CalculateEndDate    _md5                ga_desktop_cliplayer pathspec
# CalculateTransitServiceFrequency _msi                ga_desktop_copydatasetfrombigdataconnection pdb
# CentralFeature      _multibytecodec     ga_desktop_createbigdataconnectionfile pefile
# ClassifyIndoorPathways _multiprocessing    ga_desktop_createbuffers peutils
# ClassifyPointCloudUsingTrainedModelExecute _opcode             ga_desktop_createspacetimecube phototopoint
# ClassifyPointCloudUsingTrainedModelExtractParameters _operator           ga_desktop_describedataset pickle
# CollectEvents       _osx_support        ga_desktop_detectincidents pickleshare
# CompressFileGeodatabaseData _overlapped         ga_desktop_dissolveboundaries pickletools
# ConfigureIndoorPositioning _pickle             ga_desktop_duplicatedatasetfrombigdataconnection pip
# ConnectNetworkDatasetTransitSourcesToStreets _py_abc             ga_desktop_findPointClusters pipes
# ConversionUtils     _pydecimal          ga_desktop_finddwelllocations pkg_resources
# CopyExtendedProperties _pyio               ga_desktop_findhotspots pkgutil
# CopyJobFiles        _pyrsistent_version ga_desktop_findsimilarlocations platform
# CreateDriveTimeAreas_dt _pytest             ga_desktop_forestbasedclassificationandregression plistlib
# CreateFeaturesFromTextFile _queue              ga_desktop_generalizedlinearregression pluggy
# CreateIndoorsDatabase _random             ga_desktop_groupbyproximity poplib
# CreateJobForTask    _server_admin       ga_desktop_joinfeatures posixpath
# CreateSQLiteDatabase _sha1               ga_desktop_mergelayers pprint
# CreateTaskGroupJobs _sha256             ga_desktop_overlaylayers pro_notebook_integration
# CreateUPDM          _sha3               ga_desktop_previewdatasetfrombigdataconnection profile
# DEChartUtils        _sha512             ga_desktop_reconstructtracks prometheus_client
# DEFieldStatisticsToTable _signal             ga_desktop_refreshbigdataconnectionfile prompt_toolkit
# DefenseUtilities    _sitebuiltins       ga_desktop_removedatasetfrombdc pstats
# DirToCatalog        _socket             ga_desktop_snaptolines psutil
# DirToGeodatabase    _sqlite3            ga_desktop_summarizeattributes pty
# DirToMosaic         _sre                ga_desktop_summarizecenteranddispersion pvectorc
# DirToNewMosaic      _ssl                ga_desktop_summarizewithin py
# DirectionalMean     _stat               ga_desktop_traceproximityevents py_compile
# ErrorUtils          _string             ga_desktop_updatebdcdatasetproperties pyarrow
# EvaluatePointCloudClassificationModelConfusionMatrix _strptime           ga_server_aggregatepoints pybind11
# ExcelToTable        _struct             ga_server_appenddata pyclbr
# ExcelToTableX       _symtable           ga_server_buildmultivariablegrid pycodestyle
# ExifUtils           _testbuffer         ga_server_calculatedensity pycparser
# ExploratoryRegression _testcapi           ga_server_calculatefield pydoc
# ExportGeneralizedData _testconsole        ga_server_calculatemotionstatistics pydoc_data
# ExportRasters       _testimportmultiple ga_server_cliplayer pyexpat
# ExportWebMap        _testmultiphase     ga_server_copytodatastore pyflakes
# ExportXYV           _thread             ga_server_createbuffers pygments
# ExtractData         _threading_local    ga_server_createspacetimecube pylab
# FabricForArcMapToArcGISPro _tkinter            ga_server_describedataset pyodbc
# FeatureclassConversion _tracemalloc        ga_server_detectincidents pyparsing
# FeaturesToGPX       _warnings           ga_server_dissolveboundaries pyrsistent
# FeaturesToGTFSShapes _weakref            ga_server_finddwelllocations pytest
# FeaturesToGTFSStops _weakrefset         ga_server_findhotspots pytz
# FindClosestFacilities _win32sysloader     ga_server_findpointclusters pywintypes
# FindHotSpots_standard _winapi             ga_server_findsimilarlocations queue
# FloorplansToIndoors _yaml               ga_server_forestbasedclassificationandregression quopri
# GLR                 abc                 ga_server_generalizedlinearregression random
# GPXtoFeatures       addGPSMetadataFields ga_server_geographicallyweightedregression rapathutils
# GTFSShapesToFeatures aggregatepoints_standard ga_server_groupbyproximity rastertofeatures
# GTFSStopsToFeatures aifc                ga_server_joinfeatures rautils
# GTFSToNetworkDatasetTransitSources analysisutils       ga_server_mergelayers re
# GWR                 antigravity         ga_server_overlaylayers regex
# GeneralG            aolutils            ga_server_reconstructtracks reprlib
# GenerateFacilityEntryways appdirs             ga_server_snaptolines requests
# GenerateFloorTransitions arceditor           ga_server_summarizeattributes requests_kerberos
# GenerateIndoorPathways arcengine           ga_server_summarizecenteranddispersion requests_negotiate_sspi
# GenerateOccupantFeatures arcenginegeodb      ga_server_summarizewithin requests_ntlm
# GenerateServiceAreas arcgis              ga_server_traceproximityevents requests_oauthlib
# GenerateShapesFeaturesFromGTFS arcgisscripting     ga_spark            requests_toolbelt
# GenerateTessellation arcinfo             gapy                rlcompleter
# GenerateTopographicContours arcpy               gautils             rmagic
# GenerateTransectLines arcpy_init          gc                  runpy
# Geoenrichment       arcpy_wmx           generate_shapes_features_from_gtfs sarl
# GetFeaturesByJobAOI arcserver           generatepointsfromlines saspy
# GetLayoutTemplatesInfo arcview             genericpath         sched
# Gi                  argparse            geoanalytics        scipy
# IPython             array               geoanalyticssoap    secrets
# ImportGeneralizationData asn1crypto          geomet              select
# IndoorsUtilsModule  ast                 getopt              selectors
# InsertTaskGroup     asynchat            getpass             send2trash
# InterpolatePoints_standard asyncio             gettext             setuptools
# IsoClusterUnsupervised asyncore            glob                shapefile
# KFunction           atexit              gtfs_shapes_to_features shelve
# LocalMoran          atomicwrites        gtfs_stops_to_features shlex
# MeanCenter          attr                gtfs_to_network_dataset_transit_sources shutil
# MedianCenter        audioop             gtfs_utils          signal
# MoransI             autoreload          gzip                simplegeneric
# MoransI_Increment   avrpb               h5py                site
# MoransI_Step        avrpr               hashlib             six
# MultiRingBuffer     backcall            heapq               slamsce
# MultivariateClustering bapy                hmac                smtpd
# NAUtils             base64              hostedgp            smtplib
# NearestNeighbor     bdb                 html                sndhdr
# NeighborhoodSummaryStatistics binascii            html5lib            socket
# Network2SWM         binhex              http                socketserver
# NetworkSWM          bisect              idlelib             socks
# NewScriptTemplate   black               idna                sockshandler
# OLS                 blackd              imaplib             spatial_reference_helper
# OpenSSL             bleach              imghdr              splitbyattribute
# OptimizedHotSpotAnalysis blib2to3            imp                 sqlalchemy
# OptimizedOutlierAnalysis blinker             importe00           sqlite3
# PIL                 brotli              importlib           sre_compile
# Partition           bufferUtils         importlib_metadata  sre_constants
# PointToLine         builtins            indoorsdatapy       sre_parse
# PreparePointCloudTrainingDataHistogram bz2                 indoorsprotocol     ssl
# ProcessRestRequest  cProfile            indoorssql          sspi
# PyPDF2              cached_property     iniconfig           sspicon
# RasterConversion    cachetools          inspect             stat
# SABRE               calculatePluginOutput intel               statistics
# SAS2Table           calculate_transit_service_frequency interpolate         storagecapacity
# SAS_Utilities       calculate_transit_service_frequency_od_config io                  storemagic
# SKATER              calculate_transit_service_frequency_sa_config ipaddress           streamlink
# SSCalculateRate     calculatecostpath   ips                 string
# SSClearSelection    calculatecostpathpoly ipykernel           stringprep
# SSCluster           calculatedistance   ipykernel_launcher  struct
# SSColocation        calculategeometry   ipython_genutils    subprocess
# SSConvertFieldType  calculatenetwork    ipywidgets          summarizeraster
# SSCube              calculatetravelcost isodate             sunau
# SSCubeObject        calendar            isympy              swat
# SSCubeUtilities     certifi             itertools           symbol
# SSDataObject        certifi_win32       jdcal               sympy
# SSDataReduction     cffi                jedi                sympyprinting
# SSEncodeField       cftime              jinja2              symtable
# SSForest            cgi                 json                sys
# SSImpute            cgitb               json5               sysconfig
# SSMGWR              chardet             jsonschema          tabnanny
# SSOptimal           chunk               jupyter             tarfile
# SSPanel             classifyobjectsusingdl jupyter_client      telnetlib
# SSPanelObject       classifypixelsusingdl jupyter_console     tempfile
# SSPresenceOnlyPrediction click               jupyter_contrib_core terminado
# SSReclassifyField   cmath               jupyter_contrib_nbextensions tessellate
# SSReport            cmd                 jupyter_core        testpath
# SSReportXML         code                jupyter_highlight_selected_word textwrap
# SSSpatialThinning   codecs              jupyter_nbextensions_configurator this
# SSStandardizeField  codeop              jupyterlab          threading
# SSStringFormatting  collections         jupyterlab_server   time
# SSTSSmoothing       colorama            jwt                 timeit
# SSTimeSeries        colorsys            keyring             tkinter
# SSTimeUtilities     compileall          keyword             token
# SSTransformField    concurrent          kiwisolver          tokenize
# SSUtilities         configparser        latex_envs          toml
# SWM2Table           connect_network_dataset_transit_sources_to_streets lerc                tornado
# SendEmailWithZip    contextlib          lib2to3             trace
# SetDataWorkspace    contextvars         libfuturize         traceback
# SetNextTask         convert_spatial_units libpasteurize       tracemalloc
# SetProductionProperties copy                linecache           traitlets
# SetTaskGroupDependencies copyreg             locale              tty
# SetTaskList         createbuffers_sa    logging             turtle
# SetTaskStatus       crypt               lxml                turtledemo
# ShareAsRouteLayers  cryptography        lzma                typed_ast
# Similarity          csv                 macpath             types
# SkylineGraphPolarGraph ctypes              mailbox             typing
# StandardDistance    curses              mailcap             typing_extensions
# StandardEllipse     cycler              markupsafe          ujson
# Stats               cythonmagic         marshal             unicodedata
# SummarizeNearby_standard dataclasses         matchphotostorowsbytime unittest
# SummarizeWithin_standard datetime            math                urllib
# Table2SAS           dateutil            matplotlib          urllib3
# TableConversion     dbm                 mccabe              uu
# TableToExcel        decimal             mergelayers_sa      uuid
# ThinIndoorPathways  decorator           mimetypes           venv
# ThreeD_Utilities    defenseConversionToolUtilities minMajority         viewshed
# TimeSeriesCluster   defenseConversionTools mistune             warnings
# TopoWorkflowUtilities defenseDistanceAndDirectionTools mkl                 watershed
# TopographicGeneralizationUtilities defenseDistanceAndDirectionUtilities mkl_fft             wave
# TrainDeepLearningModel defenseGRGReferenceGrid mkl_random          wcwidth
# Transpose           defenseGRGTools     mmap                weakref
# UnzipCellAndImport  defenseGRGUtilities modulefinder        webbrowser
# UpdateExtendedProperty defenseHelper       mpmath              webencodings
# UpdatePropertyCount defenseVisibilityTools msilib              wheel
# UpdateTaskGroupMetrics defenseVisibilityUtilities msrest              widgetsnbextension
# Weights             defusedxml          msvcrt              win32api
# WeightsUtilities    density             multiprocessing     win32ctypes
# WriteFeaturesToTextFile despatch            mypy_extensions     win32security
# XYTableToPoint      detectobjectsusingdl nat                 win32timezone
# __future__          determinepolyline   nbconvert           win_inet_pton
# _abc                difflib             nbformat            wincertstore
# _ast                dis                 netCDF4             winkerberos
# _asyncio            dissolveboundaries_sa netrc               winpty
# _bisect             distanceaccumulation networkx            winreg
# _black_version      distanceallocation  newfile             winsound
# _blake2             distutils           nibble              wrapt
# _bootlocale         doctest             nntplib             wsgiref
# _bz2                dummy_threading     nose                x86cpu
# _cffi_backend       email               notebook            xarray
# _codecs             encodings           nt                  xdrlib
# _codecs_cn          ensurepip           ntlm_auth           xlrd
# _codecs_hk          entrypoints         ntpath              xlwt
# _codecs_iso2022     enum                ntsecuritycon       xml
# _codecs_jp          errno               nturl2path          xmlrpc
# _codecs_kr          et_xmlfile          numbers             xxlimited
# _codecs_tw          fastcache           numexpr             xxsubtype
# _collections        faulthandler        numpy               yaml
# _collections_abc    features_to_gtfs_shapes oauthlib            zipapp
# _compat_pickle      features_to_gtfs_stops odlinks             zipfile
# _compression        featuretoraster     olefile             zipimport
# _contextvars        filecmp             opcode              zipp
# _csv                fileinput           openpyxl            zlib
# _ctypes             fill                operator            zmq
# _ctypes_test        firstfile           optimalpathasline   zonalstatastable
# _datetime           flake8              optimalpathasraster
# _decimal            flowaccumulation    optimalregionconnections
# _distutils_hack     flowdirection       optparse
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
import newfile.py
# Out:
# ['c:\\program files\\arcgis\\pro\\Java\\runtime\\spark\\python\\lib\\pyspark.zip', 'c:\\program files\\arcgis\\pro\\Java\\runtime\\spark\\python\\lib\\py4j-0.10.9-src.zip', 'C:\\Users\\s1021929', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcPy', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\python37.zip', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\DLLs', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3', '', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages', 'C:\\Program Files\\ArcGIS\\Pro\\bin', 'C:\\Program Files\\ArcGIS\\Pro\\Resources\\ArcToolbox\\Scripts', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\future-0.18.2-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pytz-2020.1-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32_ctypes-0.2.0-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\pywin32security', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\sympy-1.5.1-py3.7.egg', 'C:\\Program Files\\ArcGIS\\Pro\\bin\\Python\\envs\\arcgispro-py3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\s1021929\\.ipython']
#
# Please wait a moment while I gather a list of all available modules...
#
# AddGeometryAttributes _dummy_thread       flowdistance        ordlookup
# AddVehicleRoutingProblemBreaks _elementtree        fnmatch             os
# AddVehicleRoutingProblemRoutes _functools          formatter           osgeo
# AggregatePointsCore _hashlib            fractions           osgeo_utils
# BatchDefineSR       _heapq              ftplib              overlaylayers_sa
# BatchProject        _imp                functools           packaging
# BatchPyramids       _io                 future              pandas
# BatchStats          _json               ga_desktop_aggregatepoints pandocfilters
# BivariateDependence _locale             ga_desktop_appenddata parser
# CalculateAreas      _lsprof             ga_desktop_calculatedensity parso
# CalculateDensity_standard _lzma               ga_desktop_calculatefield past
# CalculateDistanceBand _markupbase         ga_desktop_calculatemotionstatistics pathlib
# CalculateEndDate    _md5                ga_desktop_cliplayer pathspec
# CalculateTransitServiceFrequency _msi                ga_desktop_copydatasetfrombigdataconnection pdb
# CentralFeature      _multibytecodec     ga_desktop_createbigdataconnectionfile pefile
# ClassifyIndoorPathways _multiprocessing    ga_desktop_createbuffers peutils
# ClassifyPointCloudUsingTrainedModelExecute _opcode             ga_desktop_createspacetimecube phototopoint
# ClassifyPointCloudUsingTrainedModelExtractParameters _operator           ga_desktop_describedataset pickle
# CollectEvents       _osx_support        ga_desktop_detectincidents pickleshare
# CompressFileGeodatabaseData _overlapped         ga_desktop_dissolveboundaries pickletools
# ConfigureIndoorPositioning _pickle             ga_desktop_duplicatedatasetfrombigdataconnection pip
# ConnectNetworkDatasetTransitSourcesToStreets _py_abc             ga_desktop_findPointClusters pipes
# ConversionUtils     _pydecimal          ga_desktop_finddwelllocations pkg_resources
# CopyExtendedProperties _pyio               ga_desktop_findhotspots pkgutil
# CopyJobFiles        _pyrsistent_version ga_desktop_findsimilarlocations platform
# CreateDriveTimeAreas_dt _pytest             ga_desktop_forestbasedclassificationandregression plistlib
# CreateFeaturesFromTextFile _queue              ga_desktop_generalizedlinearregression pluggy
# CreateIndoorsDatabase _random             ga_desktop_groupbyproximity poplib
# CreateJobForTask    _server_admin       ga_desktop_joinfeatures posixpath
# CreateSQLiteDatabase _sha1               ga_desktop_mergelayers pprint
# CreateTaskGroupJobs _sha256             ga_desktop_overlaylayers pro_notebook_integration
# CreateUPDM          _sha3               ga_desktop_previewdatasetfrombigdataconnection profile
# DEChartUtils        _sha512             ga_desktop_reconstructtracks prometheus_client
# DEFieldStatisticsToTable _signal             ga_desktop_refreshbigdataconnectionfile prompt_toolkit
# DefenseUtilities    _sitebuiltins       ga_desktop_removedatasetfrombdc pstats
# DirToCatalog        _socket             ga_desktop_snaptolines psutil
# DirToGeodatabase    _sqlite3            ga_desktop_summarizeattributes pty
# DirToMosaic         _sre                ga_desktop_summarizecenteranddispersion pvectorc
# DirToNewMosaic      _ssl                ga_desktop_summarizewithin py
# DirectionalMean     _stat               ga_desktop_traceproximityevents py4j
# ErrorUtils          _string             ga_desktop_updatebdcdatasetproperties py_compile
# EvaluatePointCloudClassificationModelConfusionMatrix _strptime           ga_server_aggregatepoints pyarrow
# ExcelToTable        _struct             ga_server_appenddata pybind11
# ExcelToTableX       _symtable           ga_server_buildmultivariablegrid pyclbr
# ExifUtils           _testbuffer         ga_server_calculatedensity pycodestyle
# ExploratoryRegression _testcapi           ga_server_calculatefield pycparser
# ExportGeneralizedData _testconsole        ga_server_calculatemotionstatistics pydoc
# ExportRasters       _testimportmultiple ga_server_cliplayer pydoc_data
# ExportWebMap        _testmultiphase     ga_server_copytodatastore pyexpat
# ExportXYV           _thread             ga_server_createbuffers pyflakes
# ExtractData         _threading_local    ga_server_createspacetimecube pygments
# FabricForArcMapToArcGISPro _tkinter            ga_server_describedataset pylab
# FeatureclassConversion _tracemalloc        ga_server_detectincidents pyodbc
# FeaturesToGPX       _warnings           ga_server_dissolveboundaries pyparsing
# FeaturesToGTFSShapes _weakref            ga_server_finddwelllocations pyrsistent
# FeaturesToGTFSStops _weakrefset         ga_server_findhotspots pyspark
# FindClosestFacilities _win32sysloader     ga_server_findpointclusters pytest
# FindHotSpots_standard _winapi             ga_server_findsimilarlocations pytz
# FloorplansToIndoors _yaml               ga_server_forestbasedclassificationandregression pywintypes
# GLR                 abc                 ga_server_generalizedlinearregression queue
# GPXtoFeatures       addGPSMetadataFields ga_server_geographicallyweightedregression quopri
# GTFSShapesToFeatures aggregatepoints_standard ga_server_groupbyproximity random
# GTFSStopsToFeatures aifc                ga_server_joinfeatures rapathutils
# GTFSToNetworkDatasetTransitSources analysisutils       ga_server_mergelayers rastertofeatures
# GWR                 antigravity         ga_server_overlaylayers rautils
# GeneralG            aolutils            ga_server_reconstructtracks re
# GenerateFacilityEntryways appdirs             ga_server_snaptolines regex
# GenerateFloorTransitions arceditor           ga_server_summarizeattributes reprlib
# GenerateIndoorPathways arcengine           ga_server_summarizecenteranddispersion requests
# GenerateOccupantFeatures arcenginegeodb      ga_server_summarizewithin requests_kerberos
# GenerateServiceAreas arcgis              ga_server_traceproximityevents requests_negotiate_sspi
# GenerateShapesFeaturesFromGTFS arcgisscripting     ga_spark            requests_ntlm
# GenerateTessellation arcinfo             gapy                requests_oauthlib
# GenerateTopographicContours arcpy               gautils             requests_toolbelt
# GenerateTransectLines arcpy_init          gc                  rlcompleter
# Geoenrichment       arcpy_wmx           generate_shapes_features_from_gtfs rmagic
# GetFeaturesByJobAOI arcserver           generatepointsfromlines runpy
# GetLayoutTemplatesInfo arcview             genericpath         sarl
# Gi                  argparse            geoanalytics        saspy
# IPython             array               geoanalyticssoap    sched
# ImportGeneralizationData asn1crypto          geomet              scipy
# IndoorsUtilsModule  ast                 getopt              secrets
# InsertTaskGroup     asynchat            getpass             select
# InterpolatePoints_standard asyncio             gettext             selectors
# IsoClusterUnsupervised asyncore            glob                send2trash
# KFunction           atexit              gtfs_shapes_to_features setuptools
# LocalMoran          atomicwrites        gtfs_stops_to_features shapefile
# MeanCenter          attr                gtfs_to_network_dataset_transit_sources shelve
# MedianCenter        audioop             gtfs_utils          shlex
# MoransI             autoreload          gzip                shutil
# MoransI_Increment   avrpb               h5py                signal
# MoransI_Step        avrpr               hashlib             simplegeneric
# MultiRingBuffer     backcall            heapq               site
# MultivariateClustering bapy                hmac                six
# NAUtils             base64              hostedgp            slamsce
# NearestNeighbor     bdb                 html                smtpd
# NeighborhoodSummaryStatistics binascii            html5lib            smtplib
# Network2SWM         binhex              http                sndhdr
# NetworkSWM          bisect              idlelib             socket
# NewScriptTemplate   black               idna                socketserver
# OLS                 blackd              imaplib             socks
# OpenSSL             bleach              imghdr              sockshandler
# OptimizedHotSpotAnalysis blib2to3            imp                 spatial_reference_helper
# OptimizedOutlierAnalysis blinker             importe00           splitbyattribute
# PIL                 brotli              importlib           sqlalchemy
# Partition           bufferUtils         importlib_metadata  sqlite3
# PointToLine         builtins            indoorsdatapy       sre_compile
# PreparePointCloudTrainingDataHistogram bz2                 indoorsprotocol     sre_constants
# ProcessRestRequest  cProfile            indoorssql          sre_parse
# PyPDF2              cached_property     iniconfig           ssl
# RasterConversion    cachetools          inspect             sspi
# SABRE               calculatePluginOutput intel               sspicon
# SAS2Table           calculate_transit_service_frequency interpolate         stat
# SAS_Utilities       calculate_transit_service_frequency_od_config io                  statistics
# SKATER              calculate_transit_service_frequency_sa_config ipaddress           storagecapacity
# SSCalculateRate     calculatecostpath   ips                 storemagic
# SSClearSelection    calculatecostpathpoly ipykernel           streamlink
# SSCluster           calculatedistance   ipykernel_launcher  string
# SSColocation        calculategeometry   ipython_genutils    stringprep
# SSConvertFieldType  calculatenetwork    ipywidgets          struct
# SSCube              calculatetravelcost isodate             subprocess
# SSCubeObject        calendar            isympy              summarizeraster
# SSCubeUtilities     certifi             itertools           sunau
# SSDataObject        certifi_win32       jdcal               swat
# SSDataReduction     cffi                jedi                symbol
# SSEncodeField       cftime              jinja2              sympy
# SSForest            cgi                 json                sympyprinting
# SSImpute            cgitb               json5               symtable
# SSMGWR              chardet             jsonschema          sys
# SSOptimal           chunk               jupyter             sysconfig
# SSPanel             classifyobjectsusingdl jupyter_client      tabnanny
# SSPanelObject       classifypixelsusingdl jupyter_console     tarfile
# SSPresenceOnlyPrediction click               jupyter_contrib_core telnetlib
# SSReclassifyField   cmath               jupyter_contrib_nbextensions tempfile
# SSReport            cmd                 jupyter_core        terminado
# SSReportXML         code                jupyter_highlight_selected_word tessellate
# SSSpatialThinning   codecs              jupyter_nbextensions_configurator testpath
# SSStandardizeField  codeop              jupyterlab          textwrap
# SSStringFormatting  collections         jupyterlab_server   this
# SSTSSmoothing       colorama            jwt                 threading
# SSTimeSeries        colorsys            keyring             time
# SSTimeUtilities     compileall          keyword             timeit
# SSTransformField    concurrent          kiwisolver          tkinter
# SSUtilities         configparser        latex_envs          token
# SWM2Table           connect_network_dataset_transit_sources_to_streets lerc                tokenize
# SendEmailWithZip    contextlib          lib2to3             toml
# SetDataWorkspace    contextvars         libfuturize         tornado
# SetNextTask         convert_spatial_units libpasteurize       trace
# SetProductionProperties copy                linecache           traceback
# SetTaskGroupDependencies copyreg             locale              tracemalloc
# SetTaskList         createbuffers_sa    logging             traitlets
# SetTaskStatus       crypt               lxml                tty
# ShareAsRouteLayers  cryptography        lzma                turtle
# Similarity          csv                 macpath             turtledemo
# SkylineGraphPolarGraph ctypes              mailbox             typed_ast
# StandardDistance    curses              mailcap             types
# StandardEllipse     cycler              markupsafe          typing
# Stats               cythonmagic         marshal             typing_extensions
# SummarizeNearby_standard dataclasses         matchphotostorowsbytime ujson
# SummarizeWithin_standard datetime            math                unicodedata
# Table2SAS           dateutil            matplotlib          unittest
# TableConversion     dbm                 mccabe              urllib
# TableToExcel        decimal             mergelayers_sa      urllib3
# ThinIndoorPathways  decorator           mimetypes           uu
# ThreeD_Utilities    defenseConversionToolUtilities minMajority         uuid
# TimeSeriesCluster   defenseConversionTools mistune             venv
# TopoWorkflowUtilities defenseDistanceAndDirectionTools mkl                 viewshed
# TopographicGeneralizationUtilities defenseDistanceAndDirectionUtilities mkl_fft             warnings
# TrainDeepLearningModel defenseGRGReferenceGrid mkl_random          watershed
# Transpose           defenseGRGTools     mmap                wave
# UnzipCellAndImport  defenseGRGUtilities modulefinder        wcwidth
# UpdateExtendedProperty defenseHelper       mpmath              weakref
# UpdatePropertyCount defenseVisibilityTools msilib              webbrowser
# UpdateTaskGroupMetrics defenseVisibilityUtilities msrest              webencodings
# Weights             defusedxml          msvcrt              wheel
# WeightsUtilities    density             multiprocessing     widgetsnbextension
# WriteFeaturesToTextFile despatch            mypy_extensions     win32api
# XYTableToPoint      detectobjectsusingdl nat                 win32ctypes
# __future__          determinepolyline   nbconvert           win32security
# _abc                difflib             nbformat            win32timezone
# _ast                dis                 netCDF4             win_inet_pton
# _asyncio            dissolveboundaries_sa netrc               wincertstore
# _bisect             distanceaccumulation networkx            winkerberos
# _black_version      distanceallocation  newfile             winpty
# _blake2             distutils           nibble              winreg
# _bootlocale         doctest             nntplib             winsound
# _bz2                dummy_threading     nose                wrapt
# _cffi_backend       email               notebook            wsgiref
# _codecs             encodings           nt                  x86cpu
# _codecs_cn          ensurepip           ntlm_auth           xarray
# _codecs_hk          entrypoints         ntpath              xdrlib
# _codecs_iso2022     enum                ntsecuritycon       xlrd
# _codecs_jp          errno               nturl2path          xlwt
# _codecs_kr          et_xmlfile          numbers             xml
# _codecs_tw          fastcache           numexpr             xmlrpc
# _collections        faulthandler        numpy               xxlimited
# _collections_abc    features_to_gtfs_shapes oauthlib            xxsubtype
# _compat_pickle      features_to_gtfs_stops odlinks             yaml
# _compression        featuretoraster     olefile             zipapp
# _contextvars        filecmp             opcode              zipfile
# _csv                fileinput           openpyxl            zipimport
# _ctypes             fill                operator            zipp
# _ctypes_test        firstfile           optimalpathasline   zlib
# _datetime           flake8              optimalpathasraster zmq
# _decimal            flowaccumulation    optimalregionconnections zonalstatastable
# _distutils_hack     flowdirection       optparse
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-1ce8fac59353> in <module>
# ----> 1 import newfile.py
#
# ModuleNotFoundError: No module named 'newfile.py'; 'newfile' is not a package

# %%
import newfile

# %%
print(newfiles.days_of_the_week)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ef304ae3569b> in <module>
# ----> 1 print(newfiles.days_of_the_week)
#
# NameError: name 'newfiles' is not defined

# %%
print (newfile.days_of_the_week)
# Out:
# 7

# %%
print (output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1794fb7a5286> in <module>
# ----> 1 print (output)
#
# NameError: name 'output' is not defined
